# %%
#install.packages("sp")
#install.packages("sf")
#install.packages("tricolore")
#1992, 1992, 1992, 1992

# %%
library(sf)
library(tricolore)
library(ggplot2)
library(ggtern)
# Out:
# Linking to GEOS 3.9.0, GDAL 3.2.1, PROJ 7.2.1
#
# Registered S3 methods overwritten by 'ggtern':
#   method           from
#   grid.draw.ggplot ggplot2
#   plot.ggplot      ggplot2
#   print.ggplot     ggplot2
#
# --
# Remember to cite, run citation(package = 'ggtern') for further info.
# --
#
#
# Attaching package: 'ggtern'
#
#
# The following objects are masked from 'package:ggplot2':
#
#     aes, annotate, ggplot, ggplot_build, ggplot_gtable, ggplotGrob,
#     ggsave, layer_data, theme_bw, theme_classic, theme_dark,
#     theme_gray, theme_light, theme_linedraw, theme_minimal, theme_void

# %%
file <- "C:/FUME/PopNetV2/data_prep/ams_ProjectData/PopData/1992/temp_shp/1992_dataVectorGridDivs.geojson"
gdf <- read_sf(file)
st_bbox(gdf)
#st_crs(gdf)
# Out:
#    xmin    ymin    xmax    ymax
# 3964400 3253700 3984800 3270200

# %%
gdf
# Out:
# ERROR while rich displaying an object: Error in loadNamespace(x): there is no package called 'geojsonio'
#
# Traceback:
# 1. FUN(X[[i]], ...)
# 2. tryCatch(withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler), error = outer_handler)
# 3. tryCatchList(expr, classes, parentenv, handlers)
# 4. tryCatchOne(expr, names, parentenv, handlers[[1L]])
# 5. doTryCatch(return(expr), name, parentenv, handler)
# 6. withCallingHandlers({
#  .     if (!mime %in% names(repr::mime2repr))
#  .         stop("No repr_* for mimetype ", mime, " in repr::mime2repr")
#  .     rpr <- repr::mime2repr[[mime]](obj)
#  .     if (is.null(rpr))
#  .         return(NULL)
#  .     prepare_content(is.raw(rpr), rpr)
#  . }, error = error_handler)
# 7. repr::mime2repr[[mime]](obj)
# 8. repr_geojson.sf(obj)
# 9. repr_geojson(geojsonio::geojson_list(obj), ...)
# 10. loadNamespace(x)
# 11. withRestarts(stop(cond), retry_loadNamespace = function() NULL)
# 12. withOneRestart(expr, restarts[[1L]])
# 13. doWithOneRestart(return(expr), restart)
#      grid_id l1_totalpop totalMig nld l2_children l3_students l4_mobile_adults
# 1    3454     7          0         7   5          0            2
# 2    3455     4          0         4   0          0            0
# 3    3456    10          0        10   4          1            3
# 4    3635     7          2         5   2          0            5
# 5    3637     4          1         3   1          0            1
# 6    3823     4          1         3   1          1            0
# 7    3824     6          0         6   0          0            0
# 8    3825     8          2         6   3          1            0
# 9    3826     6          0         6   1          0            1
# 10   4016     9          0         9   1          2            1
# 11   4017     2          0         2   0          0            2
# 12   4439     2          0         2   0          0            0
# 13   4618    10          5         5   5          0            4
# 14   4808     8          1         7   2          0            2
# 15   4809    11          0        11   5          1            1
# 16   4810     8          1         7   1          1            3
# 17   4817    13          0        13   4          1            1
# 18   4836     2          0         2   0          0            0
# 19   4992     2          0         2   0          0            1
# 20   4999    46          7        39  18          2           14
# 21   5000    16          2        14   6          0            4
# 22   5005     5          0         5   2          0            2
# 23   5006     9          0         9   0          3            2
# 24   5190    41          3        38  14          4            8
# 25   5191     4          0         4   0          2            0
# 26   5194     3          2         1   0          0            0
# 27   5195     5          0         5   0          1            0
# 28   5214     7          0         7   2          1            2
# 29   5381    34          0        34  12          2           12
# 30   5382    20          1        19   3          2            1
# <U+22EE>    <U+22EE> <U+22EE>    <U+22EE> <U+22EE> <U+22EE>    <U+22EE>    <U+22EE>
# 6575 37495    3          0         3   0          0            2
# 6576 37835    6          0         6   2          0            2
# 6577 38236    8          0         8   4          0            3
# 6578 38425    1          0         1   0          0            0
# 6579 38426    8          0         8   2          3            0
# 6580 38615    5          0         5   1          2            0
# 6581 38790    3          0         3   0          1            0
# 6582 38984    7          0         7   0          0            0
# 6583 38985    4          0         4   1          1            1
# 6584 39175    8          1         7   0          0            3
# 6585 39186    6          0         6   4          0            1
# 6586 39358    2          0         2   0          0            1
# 6587 39365   18          0        18   2          0            4
# 6588 39371    5          0         5   2          0            0
# 6589 39372    2          0         2   1          0            0
# 6590 39555   24          2        22   5          1           10
# 6591 39744   15          0        15   7          1            3
# 6592 39745   30          1        29   6          5            7
# 6593 39934    2          0         2   0          1            1
# 6594 39935   32          1        31  11          2            6
# 6595 40125   12          0        12   4          1            2
# 6596 40132    3          0         3   0          0            0
# 6597 40316    4          0         4   1          1            0
# 6598 40317    4          0         4   2          0            2
# 6599 40505    4          0         4   2          0            1
# 6600 40703    4          0         4   0          0            2
# 6601 41647    2          0         2   0          0            0
# 6602 42595    2          0         2   0          0            0
# 6603 42975    5          0         5   2          0            1
# 6604 43165    3          0         3   0          1            0
#      l5_not_mobile_adults l6_elderly l7_immigrants <U+22EF>        Z0_Northern_Africa
# 1     0                   0          0             <U+22EF> 0.000000
# 2     2                   2          0             <U+22EF> 0.000000
# 3     2                   0          0             <U+22EF> 0.000000
# 4     0                   0          0             <U+22EF> 0.000000
# 5     2                   0          1             <U+22EF> 0.000000
# 6     2                   0          1             <U+22EF> 0.000000
# 7     3                   3          0             <U+22EF> 0.000000
# 8     4                   0          1             <U+22EF> 0.000000
# 9     4                   0          0             <U+22EF> 0.000000
# 10    5                   0          1             <U+22EF> 0.000000
# 11    0                   0          0             <U+22EF> 0.000000
# 12    0                   2          0             <U+22EF> 0.000000
# 13    0                   1          1             <U+22EF> 0.000000
# 14    0                   4          0             <U+22EF> 0.000000
# 15    2                   2          0             <U+22EF> 0.000000
# 16    1                   2          0             <U+22EF> 0.000000
# 17    5                   2          0             <U+22EF> 0.000000
# 18    2                   0          0             <U+22EF> 0.000000
# 19    1                   0          0             <U+22EF> 0.000000
# 20    9                   3          0             <U+22EF> 4.347826
# 21    4                   2          0             <U+22EF> 0.000000
# 22    1                   0          0             <U+22EF> 0.000000
# 23    4                   0          0             <U+22EF> 0.000000
# 24   15                   0          0             <U+22EF> 2.439024
# 25    2                   0          0             <U+22EF> 0.000000
# 26    3                   0          2             <U+22EF> 0.000000
# 27    4                   0          0             <U+22EF> 0.000000
# 28    1                   1          0             <U+22EF> 0.000000
# 29    8                   0          0             <U+22EF> 0.000000
# 30   10                   4          0             <U+22EF> 0.000000
# <U+22EE>    <U+22EE>             <U+22EE>   <U+22EE>      <U+22F1> <U+22EE>
# 6575  0                   1          0             <U+22EF> 0
# 6576  2                   0          0             <U+22EF> 0
# 6577  1                   0          0             <U+22EF> 0
# 6578  1                   0          0             <U+22EF> 0
# 6579  2                   1          0             <U+22EF> 0
# 6580  2                   0          0             <U+22EF> 0
# 6581  1                   1          0             <U+22EF> 0
# 6582  6                   1          0             <U+22EF> 0
# 6583  1                   0          0             <U+22EF> 0
# 6584  1                   4          1             <U+22EF> 0
# 6585  1                   0          0             <U+22EF> 0
# 6586  1                   0          0             <U+22EF> 0
# 6587  3                   9          0             <U+22EF> 0
# 6588  3                   0          0             <U+22EF> 0
# 6589  0                   1          0             <U+22EF> 0
# 6590  5                   3          0             <U+22EF> 0
# 6591  4                   0          0             <U+22EF> 0
# 6592  8                   4          0             <U+22EF> 0
# 6593  0                   0          0             <U+22EF> 0
# 6594 12                   1          1             <U+22EF> 0
# 6595  2                   3          0             <U+22EF> 0
# 6596  1                   2          0             <U+22EF> 0
# 6597  2                   0          0             <U+22EF> 0
# 6598  0                   0          0             <U+22EF> 0
# 6599  1                   0          0             <U+22EF> 0
# 6600  1                   1          0             <U+22EF> 0
# 6601  2                   0          0             <U+22EF> 0
# 6602  1                   1          0             <U+22EF> 0
# 6603  2                   0          0             <U+22EF> 0
# 6604  2                   0          0             <U+22EF> 0
#      Z1_Northern_Africa Z0_Sub.Saharan_Africa Z1_Sub.Saharan_Africa Z0_Others
# 1          NA            0                     NA                    0.0
# 2          NA            0                     NA                    0.0
# 3          NA            0                     NA                    0.0
# 4     0.00000            0                      0                    0.0
# 5     0.00000            0                      0                    0.0
# 6     0.00000           25                    100                    0.0
# 7          NA            0                     NA                    0.0
# 8     0.00000            0                      0                    0.0
# 9          NA            0                     NA                    0.0
# 10         NA            0                     NA                    0.0
# 11         NA            0                     NA                    0.0
# 12         NA            0                     NA                    0.0
# 13    0.00000            0                      0                    0.0
# 14    0.00000            0                      0                   12.5
# 15         NA            0                     NA                    0.0
# 16    0.00000            0                      0                   12.5
# 17         NA            0                     NA                    0.0
# 18         NA            0                     NA                    0.0
# 19         NA            0                     NA                    0.0
# 20   28.57143            0                      0                    0.0
# 21    0.00000            0                      0                    0.0
# 22         NA            0                     NA                    0.0
# 23         NA            0                     NA                    0.0
# 24   33.33333            0                      0                    0.0
# 25         NA            0                     NA                    0.0
# 26    0.00000            0                      0                    0.0
# 27         NA            0                     NA                    0.0
# 28         NA            0                     NA                    0.0
# 29         NA            0                     NA                    0.0
# 30    0.00000            0                      0                    0.0
# <U+22EE>    <U+22EE>           <U+22EE>              <U+22EE>              <U+22EE>
# 6575 NA                 0.000000              NA                    0
# 6576 NA                 0.000000              NA                    0
# 6577 NA                 0.000000              NA                    0
# 6578 NA                 0.000000              NA                    0
# 6579 NA                 0.000000              NA                    0
# 6580 NA                 0.000000              NA                    0
# 6581 NA                 0.000000              NA                    0
# 6582 NA                 0.000000              NA                    0
# 6583 NA                 0.000000              NA                    0
# 6584  0                 0.000000               0                    0
# 6585 NA                 0.000000              NA                    0
# 6586 NA                 0.000000              NA                    0
# 6587 NA                 0.000000              NA                    0
# 6588 NA                 0.000000              NA                    0
# 6589 NA                 0.000000              NA                    0
# 6590  0                 4.166667              50                    0
# 6591 NA                 0.000000              NA                    0
# 6592  0                 0.000000               0                    0
# 6593 NA                 0.000000              NA                    0
# 6594  0                 0.000000               0                    0
# 6595 NA                 0.000000              NA                    0
# 6596 NA                 0.000000              NA                    0
# 6597 NA                 0.000000              NA                    0
# 6598 NA                 0.000000              NA                    0
# 6599 NA                 0.000000              NA                    0
# 6600 NA                 0.000000              NA                    0
# 6601 NA                 0.000000              NA                    0
# 6602 NA                 0.000000              NA                    0
# 6603 NA                 0.000000              NA                    0
# 6604 NA                 0.000000              NA                    0
#      Z1_Others Z0_Colonies Z1_Colonies Z0_nld    geometry
# 1     NA       0.000000          NA    100.00000 MULTIPOLYGON (((3963800 326...
# 2     NA       0.000000          NA    100.00000 MULTIPOLYGON (((3963800 326...
# 3     NA       0.000000          NA    100.00000 MULTIPOLYGON (((3963800 326...
# 4      0       0.000000     0.00000     71.42857 MULTIPOLYGON (((3963900 326...
# 5      0       0.000000     0.00000     75.00000 MULTIPOLYGON (((3963900 326...
# 6      0       0.000000     0.00000     75.00000 MULTIPOLYGON (((3964000 326...
# 7     NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964000 326...
# 8      0       0.000000     0.00000     75.00000 MULTIPOLYGON (((3964000 326...
# 9     NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964000 326...
# 10    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964100 326...
# 11    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964100 326...
# 12    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964300 326...
# 13     0       0.000000     0.00000     50.00000 MULTIPOLYGON (((3964400 326...
# 14   100       0.000000     0.00000     87.50000 MULTIPOLYGON (((3964500 326...
# 15    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964500 326...
# 16   100       0.000000     0.00000     87.50000 MULTIPOLYGON (((3964500 326...
# 17    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964500 326...
# 18    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964500 326...
# 19    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964600 326...
# 20     0       0.000000     0.00000     84.78261 MULTIPOLYGON (((3964600 326...
# 21     0       6.250000    50.00000     87.50000 MULTIPOLYGON (((3964600 326...
# 22    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964600 326...
# 23    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964600 326...
# 24     0       2.439024    33.33333     92.68293 MULTIPOLYGON (((3964700 326...
# 25    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964700 326...
# 26     0       0.000000     0.00000     33.33333 MULTIPOLYGON (((3964700 326...
# 27    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964700 326...
# 28    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964700 326...
# 29    NA       0.000000          NA    100.00000 MULTIPOLYGON (((3964800 326...
# 30     0       0.000000     0.00000     95.00000 MULTIPOLYGON (((3964800 326...
# <U+22EE>    <U+22EE>  <U+22EE>    <U+22EE>    <U+22EE>  <U+22EE>
# 6575 NA        0           NA          100.00000 MULTIPOLYGON (((3981700 326...
# 6576 NA        0           NA          100.00000 MULTIPOLYGON (((3981900 326...
# 6577 NA        0           NA          100.00000 MULTIPOLYGON (((3982100 326...
# 6578 NA        0           NA          100.00000 MULTIPOLYGON (((3982200 326...
# 6579 NA        0           NA          100.00000 MULTIPOLYGON (((3982200 326...
# 6580 NA        0           NA          100.00000 MULTIPOLYGON (((3982300 326...
# 6581 NA        0           NA          100.00000 MULTIPOLYGON (((3982400 326...
# 6582 NA        0           NA          100.00000 MULTIPOLYGON (((3982500 326...
# 6583 NA        0           NA          100.00000 MULTIPOLYGON (((3982500 326...
# 6584  0        0            0           87.50000 MULTIPOLYGON (((3982600 326...
# 6585 NA        0           NA          100.00000 MULTIPOLYGON (((3982600 326...
# 6586 NA        0           NA          100.00000 MULTIPOLYGON (((3982700 326...
# 6587 NA        0           NA          100.00000 MULTIPOLYGON (((3982700 326...
# 6588 NA        0           NA          100.00000 MULTIPOLYGON (((3982700 326...
# 6589 NA        0           NA          100.00000 MULTIPOLYGON (((3982700 326...
# 6590  0        0            0           91.66667 MULTIPOLYGON (((3982800 326...
# 6591 NA        0           NA          100.00000 MULTIPOLYGON (((3982900 326...
# 6592  0        0            0           96.66667 MULTIPOLYGON (((3982900 326...
# 6593 NA        0           NA          100.00000 MULTIPOLYGON (((3983000 326...
# 6594  0        0            0           96.87500 MULTIPOLYGON (((3983000 326...
# 6595 NA        0           NA          100.00000 MULTIPOLYGON (((3983100 326...
# 6596 NA        0           NA          100.00000 MULTIPOLYGON (((3983100 326...
# 6597 NA        0           NA          100.00000 MULTIPOLYGON (((3983200 326...
# 6598 NA        0           NA          100.00000 MULTIPOLYGON (((3983200 326...
# 6599 NA        0           NA          100.00000 MULTIPOLYGON (((3983300 326...
# 6600 NA        0           NA          100.00000 MULTIPOLYGON (((3983400 326...
# 6601 NA        0           NA          100.00000 MULTIPOLYGON (((3983900 326...
# 6602 NA        0           NA          100.00000 MULTIPOLYGON (((3984400 326...
# 6603 NA        0           NA          100.00000 MULTIPOLYGON (((3984600 326...
# 6604 NA        0           NA          100.00000 MULTIPOLYGON (((3984700 326...

# %%
neigh <- read_sf("C:/FUME/PopNetV2/data_prep/ams_ProjectData/AncillaryData/adm/neighborhood_orig.geojson")
class(neigh)
# Out:
# [1] "sf"         "tbl_df"     "tbl"        "data.frame"

# %%
# reproject data
neighRe <- st_transform(neigh,st_crs(gdf))
#st_crs(neighRe)

# %%
P <- as.data.frame(gdf) 
# color-code each composition and return a corresponding color key
colors_and_legend <- Tricolore(P,'Z0_nld','Z0_EuropeEUnoLocal','Z0_Latin_America_and_the_Caribbean' )
# the color-coded compositions
head(colors_and_legend$rgb)
colors_and_legend$key

# color-code the data set and generate a color-key
tric <- Tricolore(P,
    p1 = 'Z0_nld', p2 = 'Z0_EuropeEUnoLocal', p3 = 'Z0_Latin_America_and_the_Caribbean')

# add the vector of colors to the `example` data
P$educ_rgb <- tric$rgb
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# [1] "#CFB000" "#CFB000" "#CFB000" "#CFB000" "#CFB000" "#CFB000"
# Warning message:
# "Removed 52 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "Ignoring unknown aesthetics: z"
# plot without title

# %% [markdown]
# ### Migrant and local Population in Amsterdam per District (not centered)

# %%
tric_lf_non_centered <- Tricolore(P, breaks = Inf,
                                  'Z0_nld', 'Z0_EuropeEUnoLocal', 'Z0_Latin_America_and_the_Caribbean')

P$rgb_lf_non_centered <- tric_lf_non_centered$rgb

o <- ggplot(P) +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_non_centered, geometry = geometry),colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(tric_lf_non_centered$key +
                   theme(plot.background = element_rect(colour = "transparent", fill="transparent"),
                        text=element_text(size=4))+
                     labs(L = 'NLD', T = 'Europe EU', R = 'Latin America')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Population Distribution in Amsterdam (%), 1992',
           subtitle = 'Local Population, European EU & Latin American migrants') 
ggsave(o, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistrib_GCncen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 181 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image

# %% [markdown]
# ### Migrant and local Population in Amsterdam per District (centered)

# %%
tric_lf_centered <-
  Tricolore(P,
         'Z0_nld', 'Z0_EuropeEUnoLocal', 'Z0_Latin_America_and_the_Caribbean',
        center = NA, crop = TRUE)

P$rgb_lf_centered <- tric_lf_centered$rgb

o <- ggplot(P) +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_centered, geometry = geometry),colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(
          tric_lf_centered$key +
            theme(plot.background = element_rect(colour = "transparent", fill="transparent"),
                            text=element_text(size=4))+
            labs(L = 'NLD', T = 'Europe EU', R = 'Latin America')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Population Distribution in Amsterdam (%), 1992',
           subtitle = 'Local Population, European EU & Latin American migrants')
ggsave(o, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistrib_GCcen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 181 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image

# %% [markdown]
# # Migrant Population in Amsterdam per District_ group0 (not centered)
# ####  EU,LAC,NAf

# %%
tric_lf_non_centered <- Tricolore(P, breaks = Inf,
                                  'Z0_Northern_Africa', 'Z0_EuropeEUnoLocal', 'Z0_Latin_America_and_the_Caribbean',)

P$rgb_lf_non_centered <- tric_lf_non_centered$rgb

o <- ggplot(P) +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_non_centered, geometry = geometry), colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(tric_lf_non_centered$key +
                   theme(plot.background = element_rect(colour = "transparent", fill="transparent"),
                        text=element_text(size=4))+
                     labs(L = 'Northern Africa', T = 'Europe EU', R = 'Latin America')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Distribution of Migrants in Amsterdam (%), 1992',
           subtitle = 'Migration from Europe EU, Latin America & Northern Africa') 
ggsave(o, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistribMig_GC0ncen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 935 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image

# %% [markdown]
# #### Migrant Population in Amsterdam per District_group0 (centered)

# %%
tric_lf_centered <-
  Tricolore(P,
        'Z0_Northern_Africa', 'Z0_EuropeEUnoLocal', 'Z0_Latin_America_and_the_Caribbean',
        center = NA, crop = TRUE)

P$rgb_lf_centered <- tric_lf_centered$rgb

o <- ggplot() +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_centered, geometry = geometry),colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(
          tric_lf_centered$key +
            theme(plot.background = element_rect(colour = "transparent", fill="transparent"),
                            text=element_text(size=4))+
            labs(L = 'Northern Africa', T = 'Europe EU', R = 'Latin America')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Distribution of Migrants in Amsterdam (%), 1992',
           subtitle = 'Migration from Europe EU, Latin America & Northern Africa')

ggsave(o, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistribMig_GC0cen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 935 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image

# %% [markdown]
# ### Group1 : LAC, NAf, WA_ centered

# %%
tric_lf_centered <-
  Tricolore(P,
        'Z0_Northern_Africa', 'Z0_Western_Asia', 'Z0_Latin_America_and_the_Caribbean',
        center = NA, crop = TRUE)

P$rgb_lf_centered <- tric_lf_centered$rgb

e <- ggplot() +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_centered, geometry = geometry), colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(
          tric_lf_centered$key +
            theme(plot.background = element_rect(colour = "transparent", fill="transparent"),
                            text=element_text(size=4))+
            labs(L = 'Northern Africa', T = 'Western Asia', R = 'Latin America')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Distribution of Migrants in Amsterdam (%), 1992',
           subtitle = 'Migration from Latin America, Northern Africa & Western Asia')

ggsave(e, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistribMig_GC1cen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 1369 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image

# %% [markdown]
# #### Group1 : LAC, NAf, WA_ not centered

# %%
tric_lf_non_centered <- Tricolore(P, breaks = Inf,
                                  'Z0_Northern_Africa', 'Z0_Western_Asia', 'Z0_Latin_America_and_the_Caribbean',)

P$rgb_lf_non_centered <- tric_lf_non_centered$rgb

o <- ggplot(P) +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_non_centered, geometry = geometry), colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(tric_lf_non_centered$key +
                   theme(plot.background = element_rect(colour = "transparent", fill="transparent"),
                        text=element_text(size=4))+
                     labs(L = 'Northern Africa', T = 'Western Asia', R = 'Latin America')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Distribution of Migrants in Amsterdam (%), 1992',
           subtitle = 'Migration from Latin America, Northern Africa & Western Asia') 
ggsave(o, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistribMig_GC1ncen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 1369 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image

# %%
tric_lf_centered <-
  Tricolore(P,
        'Z0_Northern_Africa', 'Z0_Western_Asia', 'Z0_Sub.Saharan_Africa',
        center = NA, crop = TRUE)

P$rgb_lf_centered <- tric_lf_centered$rgb

e <- ggplot() +
      geom_sf(data = neighRe, fill = "transparent", color = "black", size = 0.1) +
      geom_sf(data=P, aes(fill = rgb_lf_centered, geometry = geometry), colour = NA) +
      scale_fill_identity() +
      annotation_custom(
        ggplotGrob(
          tric_lf_centered$key +
            theme(plot.background = element_rect(colour = "transparent", fill = "transparent"),
                            text=element_text(size=4))+
            labs(L = 'Northern Africa', T = 'Western Asia', R = 'Sub-Saharan Africa')),
        xmin = 3957000, xmax = 3973000, ymin = 3252800, ymax = 3258800
      ) +
      theme_void() +
      coord_sf(datum = NA) +
      labs(title = 'Distribution of Migrants in Amsterdam (%), 1992',
           subtitle = 'Migration from Northern Africa, Western Asia & Sub-Saharan Africa')

ggsave(e, filename = "C:/FUME/PopNetV2/data_prep/ams_ProjectData/Visualizations/images/tricolore/gridcells/tricolore_PopDistribMig_GC2cen_1992.png",  bg = "transparent")
# Out:
# Warning message:
# "Ignoring unknown aesthetics: z"
# Coordinate system already present. Adding new coordinate system, which will replace the existing one.
#
# Warning message:
# "Removed 2139 rows containing missing values (geom_point)."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Warning message:
# "It is deprecated to specify `guide = FALSE` to remove a guide. Please use `guide = "none"` instead."
# Saving 6.67 x 6.67 in image
